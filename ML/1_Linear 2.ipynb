# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
# Out:
# C:\Users\Muhammad_Talha\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv(r'C:\Users\Muhammad_Talha\Downloads\COHORT 7\Week 1 + 2 + 3\Untitled Folder\SLR_TvMarketing.csv')
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
x,y = df[['TV']],df['Sales']

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.2)

# %%
print(train_x.shape,test_x.shape,train_y.shape,test_y.shape)
# Out:
# (160, 1) (40, 1) (160,) (40,)

# %%
model = LinearRegression()

# %%
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
pred_y = model.predict(test_x)

# %%
mean_absolute_error(test_y,pred_y)
# Out:
# 2.6147829272168956

# %%
plt.plot(range( 0,len(test_y)),test_y)
plt.plot(range (0,len(test_y)),pred_y)

# %%
plt.plot(range( 0,10),test_y[0:10],label ='Actuall')
plt.plot(range (0,10),pred_y[0:10],label = 'predicted' )
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()

# %%
accuracy = r2_score(test_y,pred_y)
accuracy
# Out:
# 0.6389484193566901

# %%
plt.plot(range(0, 10), test_y[0:10], label='Actual')
plt.plot(range(0, 10), pred_y[0:10], label='Predicted')
plt.axhline(mean_test_y, color='red', linestyle='--', label='Mean of Actuals')  # Horizontal line

plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()
